# %% [markdown]
# <table style="width:100%; font-size:11pt; border-collapse:collapse">
#     <tr>
#         <td colspan="2"
#             style="border: 1px #44a305 solid;
#                    background-color:#F4F9E6;
#                    color:#6ba340;
#                    text-align:center;
#                    font-weight:bold;
#                    padding:8px;">
#             Universidad de Oriente
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px #44a305 solid;
#                    background-color:#F4F9E6;
#                    color:#6ba340;
#                    width:50%;
#                    text-align:center;
#                    padding:6px;">
#                             Métodos Numéricos
#         </td>
#         <td style="border: 1px #44a305 solid;
#                    background-color:#F4F9E6;
#                    color:#6ba340;
#                    width:50%;
#                    text-align:center;
#                    padding:6px;">
#             Clase 16 - Método de la bisección
#         </td>
#     </tr>
#     <tr>
#
#
# </table>

# %% [markdown]
# ## Ejemplo
#
# Una partícula parte del reposo sobre un plano inclinado uniforme. Al final de $t$ segundos, la posición del objeto está dada por
# $$x(t)=-\dfrac{g}{2\omega^2} \left(\frac{e^{\omega t}-e^{-\omega t}}{2} -\sin (\omega t)\right)$$
# Suponga que la partícula se desplazó $1.7$ pies en dirección negativa en $1 \ s$. Encontrar con una exactitud de $10^{-5}$, la rapidez $\omega$. Suponga que $g=32.17 \ pies/s^2$ y que $\omega \in [0,1]$

# %%
import math 
import pandas as pd
import sys

from pathlib import Path
sys.path.append(str(Path.cwd().parents[1]))

# %%
def fun(w):
    g = 32.17
    t = 1
    y = -g/(2*w**2)*((math.exp(w*t)-math.exp(-w*t))/2-math.sin(w*t))-1.7
    return y

# %%
from tools.biseccion import Biseccion

a = -1
b = 0
tol = 1e-5
maxiter = 30

x, iters, error = Biseccion(fun,a,b,tol,maxiter)

print(f"La solución obtenida fue {x}")
print(f"La cantidad de iteracione realizadas fueron {iters}")
print(f"El error que se obtuvo fue de {error}")
# Out:
# La solución obtenida fue -0.31705474853515625
# La cantidad de iteracione realizadas fueron 17
# El error que se obtuvo fue de 7.62939453125e-06

# %%
from tools.bisecciontabla import Bisecciontabla

Bisecciontabla(fun,a,b,tol,maxiter)
# Out:
#                a             b             x       Errores
# 0  -1.0000000000  0.0000000000 -0.5000000000  0.5000000000
# 1  -0.5000000000  0.0000000000 -0.2500000000  0.2500000000
# 2  -0.5000000000 -0.2500000000 -0.3750000000  0.1250000000
# 3  -0.3750000000 -0.2500000000 -0.3125000000  0.0625000000
# 4  -0.3750000000 -0.3125000000 -0.3437500000  0.0312500000
# 5  -0.3437500000 -0.3125000000 -0.3281250000  0.0156250000
# 6  -0.3281250000 -0.3125000000 -0.3203125000  0.0078125000
# 7  -0.3203125000 -0.3125000000 -0.3164062500  0.0039062500
# 8  -0.3203125000 -0.3164062500 -0.3183593750  0.0019531250
# 9  -0.3183593750 -0.3164062500 -0.3173828125  0.0009765625
# 10 -0.3173828125 -0.3164062500 -0.3168945312  0.0004882812
# 11 -0.3173828125 -0.3168945312 -0.3171386719  0.0002441406
# 12 -0.3171386719 -0.3168945312 -0.3170166016  0.0001220703
# 13 -0.3171386719 -0.3170166016 -0.3170776367  0.0000610352
# 14 -0.3170776367 -0.3170166016 -0.3170471191  0.0000305176
# ...
